# %% [markdown]
# # 【讲人话的人工智能】第0期 - 如何用机器学习预测自己的职业生涯

# %% [markdown]
# ## 1. 为什么要看这些视频
# ### 1.我能不能做机器学习？
#
# 任何人都可以，不同人有不同的方式
#
#
#
#
# ### 2.我想做机器学习，应该如何上手？
#
# 方案一：以正规军的方式系统性学习
#
# 🌟方案二：野路子搞起，边干边学
#
#
#
# ### 3.排除常见误区
#
# 高大上的机器学习是不是多么困难的问题都能解决？
#
# 是不是越复杂的模型最厉害？
#
#
#
# ## 2. 为什么可以做到
# 1.多讲思想少推公式
#
# 2.尽量结合具体的实例
#
#
# ## 3. 问题类型以及对应的算法（算法类型以及对应能解决的问题？）
# ### 先有问题还是先有算法？
#
# 1.回归（监督学习）
#
# - 已知一个人的一系列属性（年龄/性别/毕业院校/技能熟练度..），预测能拿多少工资
#
# 2.分类（监督学习）
#
# - 已知一个人的一系列属性（年龄/性别/所在公司/工作年限...），预测是否会升职
#
# 3.聚类（非监督学习）
#
# - 已知一个小组leader手下有一堆人，想要根据他们的不同特质（技术水平/沟通能力/性格特点/家庭背景...）分成几类，采用不同的培养方式
#
# 4.智能体&环境交互（强化学习）
#
# - alphaGo下围棋，星际争霸，flappybird
# - 一个应届毕业生（智能体）毕业后进入一家公司（环境），工作和接触同事们不断打怪升级（交互），根据获得的经验（正/负向激励），提升自己（学习到的策略）
#
#
# ## 4. 几种算法的区别
# 1.监督学习
#
# 需要看参考答案（样本）来学习（训练）。已知y（label）和X（feature）求一个f（model）使得y=f(x)
# 有了f(x)以后随便来一个x都可以算出y
#
# 2.非监督学习
#
# 不需要参考答案，只根据X值的分布把样本分成几堆（和分类的区别在不知道到底分几堆）
#
# - 技术水平高&沟通能力弱一些的把高难度的任务派给他
# - 技术水平一般&沟通能力强的负责和其他部门协作，讨论需求
# - 技术水平渣渣&家庭背景硬的当大爷供起来
# - 。。。。
#
# 3.强化学习
#
# 定义智能体/环境的交互规则，奖惩措施，通过暴力or机智的搜索方式让智能体找到好的策略
#
# ## 5. 各种算法的经典模型
#
# ### sklearn(python必学) https://scikit-learn.org/
#
# regression回归
#
# classification分类
#
# clustering聚类
#
# dimension reducing降维

# %% [markdown]
# ## 思考题
# 你可以举出一些“问题以及对应的算法”的例子吗？
